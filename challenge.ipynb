# %% [markdown]
# # Task 1- Load the Social Security data about baby names

# %%
#imports

import numpy as np
import pandas as pd

# %%
# initialize variables

names = None
names_year_list = []

# %%
years = range(1880, 2018)
cols = ['Name', 'Sex', 'Number']

# %%
# loop through the files to load dataset
for year in years:
    names_year = pd.read_csv('names/yob%d.txt' % year, names=cols)
    names_year['Year'] = year
    names_year_list.append(names_year)
    
# concatenate the dataframe one dataframe
names = pd.concat(names_year_list, ignore_index=True)
names.head()
# Out:
#         Name Sex  Number  Year
# 0       Mary   F    7065  1880
# 1       Anna   F    2604  1880
# 2       Emma   F    2003  1880
# 3  Elizabeth   F    1939  1880
# 4     Minnie   F    1746  1880

# %% [markdown]
# # Task 2 – Compare popularity trend of following names in form of a nice plot accross all the years since 1880
#    a. ['Michael', 'John', 'David', 'Martin']
#
#    b. ['Emily', 'Anna', 'Claire', 'Elizabeth']

# %%
#index the data on gender, then name and then the year

names_sorted = names.set_index(['Sex','Name','Year']).sort_index(level=0)
names_sorted.head(20)
# Out:
#                     Number
# Sex Name      Year
# F   Aabha     2011       7
#               2012       5
#               2014       9
#               2015       7
#               2016       7
#     Aabriella 2008       5
#               2014       5
#               2015       5
#               2016      11
#               2017       6
#     Aada      2015       5
#     Aaden     2009       5
#     Aadhira   2012       6
#               2013      10
#               2014      13
#               2015       8
#               2016      14
#               2017      26
#     Aadhvika  2016       9
#     Aadhya    2007      10

# %%
import matplotlib.pyplot as plt

#A function which plots the values of this subset of data 
def draw(sex,name):
    sorted_subset = names_sorted.loc[sex,name]
    plt.plot(sorted_subset.index,sorted_subset.values)

# %% [markdown]
# #  Plot

# %%
#Select some names for plotting.
selected_names = ['Michael','John','David','Martin']

#Select the size of the plot
plt.figure(figsize=(20,5))

#Call the 'draw' function for each name in above list.
for name in selected_names:
    draw('M',name)
plt.title("Matplotlib popularity: A scatter")  
plt.xlabel("Year")
plt.ylabel("Number")
plt.legend(selected_names)
plt.show()

# %% [markdown]
# #  Plot

# %%
#Select the size of the plot
plt.figure(figsize=(20,5))

#Select some names for plotting.
selected_names = ['Emily','Anna','Claire','Elizabeth']

#Call the 'draw' function for each name in above list.
for name in selected_names:
    draw('F',name)
plt.title("Matplotlib popularity: A scatter")    
plt.xlabel("Year")
plt.ylabel("Number")
plt.legend(selected_names)
plt.show()

# %% [markdown]
# # Task 3 - Extract the 10 most popular -
#    a. Girl names in year 2010
#
#    b. Boy names in year 2001

# %%
import pandas as pd
data1=pd.read_csv("names/yob2010.txt",header=None, names=['Name','Sex','Number'])
data2=pd.read_csv("names/yob2001.txt",header=None, names=['Name','Sex','Number'])

# %%
# 10 popular girls name in 2010
data1[data1['Sex']=='F'].head(10)[["Name"]]
# Out:
#        Name
# 0  Isabella
# 1    Sophia
# 2      Emma
# 3    Olivia
# 4       Ava
# 5     Emily
# 6   Abigail
# 7   Madison
# 8     Chloe
# 9       Mia

# %%
# 10 popular boys name in 2010
data1[data1['Sex']=='M'].head(10)[["Name"]].reset_index(drop=True)
# Out:
#         Name
# 0      Jacob
# 1      Ethan
# 2    Michael
# 3     Jayden
# 4    William
# 5  Alexander
# 6       Noah
# 7     Daniel
# 8      Aiden
# 9    Anthony

# %%
# 10 popular girls name in 2001
data2[data2['Sex']=='F'].head(10)[["Name"]]
# Out:
#         Name
# 0      Emily
# 1    Madison
# 2     Hannah
# 3     Ashley
# 4     Alexis
# 5      Sarah
# 6   Samantha
# 7    Abigail
# 8  Elizabeth
# 9     Olivia

# %%
# 10 popular boys name in 2001
data2[data2['Sex']=='M'].head(10)[["Name"]].reset_index(drop=True)
# Out:
#           Name
# 0        Jacob
# 1      Michael
# 2      Matthew
# 3       Joshua
# 4  Christopher
# 5     Nicholas
# 6       Andrew
# 7       Joseph
# 8       Daniel
# 9      William

# %%
# 10 most popular girls & boys name in 2010.
pd.concat([data1[data1['Sex']=='F'].head(10)[["Name","Sex"]],data1[data1['Sex']=='M'].head(10)[["Name","Sex"]].reset_index(drop=True)],axis=1)
# Out:
#        Name Sex       Name Sex
# 0  Isabella   F      Jacob   M
# 1    Sophia   F      Ethan   M
# 2      Emma   F    Michael   M
# 3    Olivia   F     Jayden   M
# 4       Ava   F    William   M
# 5     Emily   F  Alexander   M
# 6   Abigail   F       Noah   M
# 7   Madison   F     Daniel   M
# 8     Chloe   F      Aiden   M
# 9       Mia   F    Anthony   M

# %%
# 10 most popular girls name & boys name in 2001 in one table
pd.concat([data2[data2['Sex']=='F'].head(10)[["Name","Sex"]],data2[data2['Sex']=='M'].head(10)[["Name","Sex"]].reset_index(drop=True)],axis=1)
# Out:
#         Name Sex         Name Sex
# 0      Emily   F        Jacob   M
# 1    Madison   F      Michael   M
# 2     Hannah   F      Matthew   M
# 3     Ashley   F       Joshua   M
# 4     Alexis   F  Christopher   M
# 5      Sarah   F     Nicholas   M
# 6   Samantha   F       Andrew   M
# 7    Abigail   F       Joseph   M
# 8  Elizabeth   F       Daniel   M
# 9     Olivia   F      William   M

# %% [markdown]
# # Extra Task - top 5 names in each year from 2001 to 2010 into single table

# %%
#index the data on gender first, then name and then the year

names_sorted = names.set_index(['Sex','Name','Year']).sort_index(level=0)
names_sorted.head(20)

names_sorted.loc['M',:,2008].sort_values('Number',ascending=False).head()
# Out:
#                   Number
# Sex Name    Year
# M   Jacob   2008   22591
#     Michael 2008   20617
#     Ethan   2008   20211
#     Joshua  2008   19200
#     Daniel  2008   19001

# %%
#Create a new DataFrame.
yob2008 = names_sorted.loc['M',:,2008].sort_values('Number',ascending=False)

#Use 'drop' method to delete columns and 'reset_index' to reset the index.
yob2008.reset_index().drop(['Sex','Year','Number'],axis=1).head()
# Out:
#       Name
# 0    Jacob
# 1  Michael
# 2    Ethan
# 3   Joshua
# 4   Daniel

# %%
#Function yearwise to sort, drop and reset the index for single year.
def yearwise(sex,year):
    space = names_sorted.loc[sex,:,year].sort_values('Number',ascending=False).reset_index()
    space = space.drop(['Sex','Year','Number'],axis=1).head(5)
    space.columns = [year]
    space.index = space.index + 1
    return space

#Function sortring to call the 'yearwise_sorting'.
def sortring(sex,y1,y2):
    years = [yearwise(sex,year) for year in range(y1,y2+1)]
    return years[0].join(years[1:])

#calling function for 2001 to 2010.
print(sortring('M',2001,2010))
# Out:
#           2001     2002     2003     2004     2005     2006     2007     2008  \
# 1        Jacob    Jacob    Jacob    Jacob    Jacob    Jacob    Jacob    Jacob
# 2      Michael  Michael  Michael  Michael  Michael  Michael  Michael  Michael
# 3      Matthew   Joshua   Joshua   Joshua   Joshua   Joshua    Ethan    Ethan
# 4       Joshua  Matthew  Matthew  Matthew  Matthew    Ethan   Joshua   Joshua
# 5  Christopher    Ethan   Andrew    Ethan    Ethan  Matthew   Daniel   Daniel
#
#         2009     2010
# 1      Jacob    Jacob
# 2      Ethan    Ethan
# 3    Michael  Michael
# 4  Alexander   Jayden
# 5    William  William

# %%
#printing top 5  girls names in each year from 2001 to 2010.
print(sortring('F',2001,2010))
# Out:
#       2001     2002     2003     2004     2005      2006      2007      2008  \
# 1    Emily    Emily    Emily    Emily    Emily     Emily     Emily      Emma
# 2  Madison  Madison     Emma     Emma     Emma      Emma  Isabella  Isabella
# 3   Hannah   Hannah  Madison  Madison  Madison   Madison      Emma     Emily
# 4   Ashley     Emma   Hannah   Olivia  Abigail  Isabella       Ava    Olivia
# 5   Alexis   Alexis   Olivia   Hannah   Olivia       Ava   Madison       Ava
#
#        2009      2010
# 1  Isabella  Isabella
# 2      Emma    Sophia
# 3    Olivia      Emma
# 4    Sophia    Olivia
# 5       Ava       Ava
